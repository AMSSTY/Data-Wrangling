# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests as rq
import json
from timeit import default_timer as timer
# %matplotlib inline

# %% [markdown]
# # 1 - Gathering Data for this Project
#
# Gather each of the three pieces of data as described below in a Jupyter Notebook titled wrangle_act.ipynb:
#
#     The WeRateDogs Twitter archive. I am giving this file to you, so imagine it as a file on hand. Download this file manually by clicking the following link:
#
#    ## 1.1 - Twitter_archive_enhanced.csv
#    File downloaded manually to library

# %%
archive = pd.read_csv('twitter-archive-enhanced.csv')
archive.sample(3)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 864   762464539388485633                    NaN                  NaN
# 1171  720415127506415616                    NaN                  NaN
# 2063  671159727754231808                    NaN                  NaN
#
#                       timestamp  \
# 864   2016-08-08 01:44:46 +0000
# 1171  2016-04-14 00:55:25 +0000
# 2063  2015-11-30 02:52:03 +0000
#
#                                                  source  \
# 864   <a href="http://twitter.com/download/iphone" r...
# 1171  <a href="http://twitter.com/download/iphone" r...
# 2063  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 864   This is Buddy. His father was a bear and his m...                  NaN
# 1171  Garden's coming in nice this year. 10/10 https...                  NaN
# 2063  This is Anthony. He just finished up his maste...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 864                        NaN                        NaN
# 1171                       NaN                        NaN
# 2063                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 864   https://twitter.com/dog_rates/status/762464539...                12
# 1171  https://twitter.com/dog_rates/status/720415127...                10
# 2063  https://twitter.com/dog_rates/status/671159727...                 5
#
#       rating_denominator     name doggo floofer pupper puppo
# 864                   10    Buddy  None    None   None  None
# 1171                  10     None  None    None   None  None
# 2063                  10  Anthony  None    None   None  None

# %% [markdown]
# ## 1.2 - Image_prediction_tsv
# The tweet image predictions, i.e., what breed of dog (or other object, animal, etc.) is present in each tweet according to a neural network. This file (image_predictions.tsv) is hosted on Udacity's servers and should be downloaded programmatically using the Requests library and the following URL: https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv

# %%
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
image_prediction_temp = rq.get(url)

with open('image_predictions.tsv', mode ='wb') as file:
    file.write(image_prediction_temp.content)
    
image_prediction = pd.read_csv('image_predictions.tsv' , sep='\t')
image_prediction.sample(3)
# Out:
#                 tweet_id                                            jpg_url  \
# 1181  738184450748633089    https://pbs.twimg.com/media/Cj6O1G9UYAAIU-1.jpg
# 1858  841833993020538882  https://pbs.twimg.com/ext_tw_video_thumb/81742...
# 218   670073503555706880    https://pbs.twimg.com/media/CUyUSuWXIAAZKYF.jpg
#
#       img_num                  p1   p1_conf  p1_dog               p2  \
# 1181        1  Bedlington_terrier  0.289471    True  standard_poodle
# 1858        1            ice_bear  0.336200   False          Samoyed
# 218         1            malamute  0.601886    True   Siberian_husky
#
#        p2_conf  p2_dog              p3   p3_conf  p3_dog
# 1181  0.173685    True  Great_Pyrenees  0.157081    True
# 1858  0.201358    True      Eskimo_dog  0.186789    True
# 218   0.340106    True      Eskimo_dog  0.050041    True

# %% [markdown]
# ## 1.3 - 'Accessing Project Data Without a Twitter Account'
#
# Due to twitter account access limitations, (Developer account request not approved) ,  the following code cell is commented out, it exists for readability, json data will be accessed using the json file provided in Twitter API section.

# %%
# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
#consumer_key = 'HIDDEN'
#consumer_secret = 'HIDDEN'
#access_token = 'HIDDEN'
#access_secret = 'HIDDEN'


#auth = OAuthHandler(consumer_key, consumer_secret)
#auth.set_access_token(access_token, access_secret)

#api = tweepy.API(auth, wait_on_rate_limit=True)

# NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:
# df_1 is a DataFrame with the twitter_archive_enhanced.csv file. You may have to
# change line 17 to match the name of your DataFrame with twitter_archive_enhanced.csv
# NOTE TO REVIEWER: this student had mobile verification issues so the following
# Twitter API code was sent to this student from a Udacity instructor
# Tweet IDs for which to gather additional data via Twitter's API
#tweet_ids = df_1.tweet_id.values
#len(tweet_ids)

# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
#count = 0
#fails_dict = {}
#start = timer()
#Save each tweet's returned JSON as a new line in a .txt file
#    with open('tweet_json.txt', 'w') as outfile:
#    This loop will likely take 20-30 minutes to run because of Twitter's rate limit
#    for tweet_id in tweet_ids:
#       count += 1
#       print(str(count) + ": " + str(tweet_id))
#       try:
#          tweet = api.get_status(tweet_id, tweet_mode='extended')
#          print("Success")
#          json.dump(tweet._json, outfile)
#          outfile.write('\n')
#       except tweepy.TweepError as e:
#          print("Fail")
#          fails_dict[tweet_id] = e
#          pass
#end = timer()
#print(end - start)
#print(fails_dict)

# %% [markdown]
# ## 1.3.1 - Json - Data file
# Each tweet's retweet count and favorite ("like") count at minimum, and any additional data you find interesting. Using the tweet IDs in the WeRateDogs Twitter archive, query the Twitter API for each tweet's JSON data using Python's Tweepy library and store each tweet's entire set of JSON data in a file called tweet_json.txt file. Each tweet's JSON data should be written to its own line. Then read this .txt file line by line into a pandas DataFrame with (at minimum) tweet ID, retweet count, and favorite count. Note: do not include your Twitter API keys, secrets, and tokens in your project submission.

# %%
# appending json file contents into a list
tweet_df = []
with open('tweet_json.txt', 'r') as tweet_file:
    for item in tweet_file:
        status = json.loads(item)
        tweet_df.append({'tweet_id': status['id'],
                        'retweet_count': status['retweet_count'],
                        'favorite_count': status['favorite_count'],
                         'full_text': status['full_text']
                       })
        
# Tweet json file will be converted into a data frame
tweet_df = pd.DataFrame(tweet_df)
tweet_df.sample(3)
# Out:
#       favorite_count                                          full_text  \
# 218            17519  This is Riley. He's making new friends. Jubila...
# 2119             600  This is Peanut. He was the World Table Tennis ...
# 790             7317  This is Loki. He knows he's adorable. One ear ...
#
#       retweet_count            tweet_id
# 218            4244  850145622816686080
# 2119            249  670408998013820928
# 790            1891  773704687002451968

# %% [markdown]
# # 2 - Quality , Tideness Assesment section
# Assessing Data for this Project
#
# After gathering each of the above pieces of data, assess them visually and programmatically for quality and tidiness issues. Detect and document at least eight (8) quality issues and two (2) tidiness issues in your wrangle_act.ipynb Jupyter Notebook. To meet specifications, the issues that satisfy the Project Motivation (see the Key Points header on the previous page) must be assessed.

# %% [markdown]
# **Quality testing:**
# - Archive Datatype incorrect (tweet_id , timestamp)
# - Columns (in_reply_to_status_id , in_reply_to_user_id  , retweeted_status_id , retweeted_status_user_id), need to be removed as they are linked to retweets.
# - Retweets are not valid oringinal tweets, need removal.
# - Null Values: many columns tend to have alot of null values.
# - Source column shows a hyberlink, needs to remove the link and exctract the real source.
# - Name column contains Nulls and non-correct names.
# - Image prediction tweet id is of type int, should be str.
# - Image prediction contains records of non - dogs. (removal)
# - Json file tweet_di is of type int, should be str.
# - text & full_text columns are indentical, one should be removed when merged.
#
# **Tidness testing**
# - Id columns dont match between tables, so number of recrods.
# - Columns ( doggo , floofer , pupper , puppo ) should be combined into a catergorial type (stages).

# %% [markdown]
# ## **2.1 - Archive table**

# %%
archive.sample(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
#
info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
image_prediction.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %% [markdown]
# ## **2.3 - Json Data File**

# %%
tweet_df.sample(5)
# Out:
#       favorite_count                                          full_text  \
# 334             3195  There's going to be a dog terminal at JFK Airp...
# 1013           10534  Guys... I said DOGS with "shark qualities" or ...
# 2215             496  This is Gòrdón. He enjoys his razberrita by po...
# 2079             647  Can't do better than this lol. 10/10 for the o...
# 1198            1339  There has clearly been a mistake. Pup did noth...
#
#       retweet_count            tweet_id
# 334             594  832645525019123713
# 1013           4548  747103485104099331
# 2215            242  668528771708952576
# 2079            105  670822709593571328
# 1198            475  716730379797970944

# %%
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 4 columns):
# favorite_count    2354 non-null int64
# full_text         2354 non-null object
# retweet_count     2354 non-null int64
# tweet_id          2354 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 73.6+ KB

# %%
tweet_df.describe()
# Out:
#        favorite_count  retweet_count      tweet_id
# count     2354.000000    2354.000000  2.354000e+03
# mean      8080.968564    3164.797366  7.426978e+17
# std      11814.771334    5284.770364  6.852812e+16
# min          0.000000       0.000000  6.660209e+17
# 25%       1415.000000     624.500000  6.783975e+17
# 50%       3603.500000    1473.500000  7.194596e+17
# 75%      10122.250000    3652.000000  7.993058e+17
# max     132810.000000   79515.000000  8.924206e+17

# %% [markdown]
# # 3 - Cleaning Section
# In this section, all data quality and tideness issues will be cleaned, this includes:
# - Dataype fixes
# - removing duplicated values
# - removing null values
# - merging columns if required
# - merging cleaned tables into a master dataframe.

# %% [markdown]
# ## **3.1 - Archive**
# dtypes test

# %%
archive.dtypes
# Out:
# tweet_id                        int64
# in_reply_to_status_id         float64
# in_reply_to_user_id           float64
# timestamp                      object
# source                         object
# text                           object
# retweeted_status_id           float64
# retweeted_status_user_id      float64
# retweeted_status_timestamp     object
# expanded_urls                  object
# rating_numerator                int64
# rating_denominator              int64
# name                           object
# doggo                          object
# floofer                        object
# pupper                         object
# puppo                          object
# dtype: object

# %%
archive['tweet_id'] = archive['tweet_id'].astype(str)
archive['in_reply_to_status_id'] = archive['in_reply_to_status_id'].astype(str)
archive['in_reply_to_user_id'] = archive['in_reply_to_user_id'].astype(str)
archive['retweeted_status_id'] = archive['retweeted_status_id'].astype(str)
archive['retweeted_status_user_id'] = archive['retweeted_status_user_id'].astype(str)
archive['timestamp'] = pd.to_datetime(archive['timestamp'])
archive['retweeted_status_timestamp'] = pd.to_datetime(archive['retweeted_status_timestamp'])

# %%
archive.dtypes
# Out:
# tweet_id                              object
# in_reply_to_status_id                 object
# in_reply_to_user_id                   object
# timestamp                     datetime64[ns]
# source                                object
# text                                  object
# retweeted_status_id                   object
# retweeted_status_user_id              object
# retweeted_status_timestamp    datetime64[ns]
# expanded_urls                         object
# rating_numerator                       int64
# rating_denominator                     int64
# name                                  object
# doggo                                 object
# floofer                               object
# pupper                                object
# puppo                                 object
# dtype: object

# %% [markdown]
# ## **3.2 - Archive drop Nulls**
# null values test

# %%
archive.retweeted_status_timestamp.isnull().sum()
# Out:
# 2175

# %%
archive.drop('retweeted_status_timestamp' , axis=1 , inplace=True)

# %%
archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 16 columns):
# tweet_id                    2356 non-null object
# in_reply_to_status_id       2356 non-null object
# in_reply_to_user_id         2356 non-null object
# timestamp                   2356 non-null datetime64[ns]
# source                      2356 non-null object
# text                        2356 non-null object
# retweeted_status_id         2356 non-null object
# retweeted_status_user_id    2356 non-null object
# expanded_urls               2297 non-null object
# rating_numerator            2356 non-null int64
# rating_denominator          2356 non-null int64
# name                        2356 non-null object
# doggo                       2356 non-null object
# floofer                     2356 non-null object
# pupper                      2356 non-null object
# puppo                       2356 non-null object
# dtypes: datetime64[ns](1), int64(2), object(13)
# memory usage: 294.6+ KB

# %% [markdown]
# ## 3.3 -  Source Column Fix

# %%
source = archive['source']
source.unique()
# Out:
# array(['<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#        '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#        '<a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>',
#        '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>'],
#       dtype=object)

# %%
archive['source'].replace(source.unique()[0],'Twitter for iPhone',inplace=True)
archive['source'].replace(source.unique()[1],'Twitter Web Client',inplace=True)
archive['source'].replace(source.unique()[2],'Vine - Make a Scene',inplace=True)
archive['source'].replace(source.unique()[3],'TweetDeck',inplace=True)
archive.source.unique()
# Out:
# array(['Twitter for iPhone', 'Twitter Web Client', 'Vine - Make a Scene',
#        'TweetDeck'], dtype=object)

# %% [markdown]
# ## 3.4 - Name Column Fix

# %%
archive['name'].replace(['None','a',' None'],'Unnammed',inplace=True)
archive.name.value_counts()
# Out:
# Unnammed        800
# Charlie          12
# Oliver           11
# Cooper           11
# Lucy             11
# Penny            10
# Lola             10
# Tucker           10
# Bo                9
# Winston           9
# the               8
# Sadie             8
# Toby              7
# Buddy             7
# an                7
# Daisy             7
# Bailey            7
# Leo               6
# Dave              6
# Stanley           6
# Jack              6
# Oscar             6
# Scout             6
# Jax               6
# Milo              6
# Koda              6
# Bella             6
# Rusty             6
# Louis             5
# Phil              5
#                ...
# Jockson           1
# Pluto             1
# BeBe              1
# Dwight            1
# Jarod             1
# Bradlay           1
# Saydee            1
# Howie             1
# Jerome            1
# Kane              1
# Willow            1
# Jeffrie           1
# Severus           1
# Shakespeare       1
# Grady             1
# Rumble            1
# Edgar             1
# Charleson         1
# unacceptable      1
# Tebow             1
# Noosh             1
# Rueben            1
# Linus             1
# Dudley            1
# Lorelei           1
# Fiji              1
# Chevy             1
# Tango             1
# Millie            1
# Newt              1
# Name: name, Length: 956, dtype: int64

# %% [markdown]
# ## **3.5 - Retweets**

# %%
retweets = archive[archive.text.str.contains('RT @')]
retweets.sample(3)
# Out:
#                tweet_id in_reply_to_status_id in_reply_to_user_id  \
# 78   877611172832227328                   nan                 nan
# 566  802247111496568832                   nan                 nan
# 469  816829038950027264                   nan                 nan
#
#               timestamp              source  \
# 78  2017-06-21 19:36:23  Twitter for iPhone
# 566 2016-11-25 20:26:31  Twitter for iPhone
# 469 2017-01-05 02:09:53  Twitter for iPhone
#
#                                                   text    retweeted_status_id  \
# 78   RT @rachel2195: @dog_rates the boyfriend and h...   8.76850772322988e+17
# 566  RT @dog_rates: Everybody drop what you're doin...  7.790560957887529e+17
# 469  RT @dog_rates: This is Betty. She's assisting ...   7.90946055508652e+17
#
#     retweeted_status_user_id  \
# 78               512804507.0
# 566             4196983835.0
# 469             4196983835.0
#
#                                          expanded_urls  rating_numerator  \
# 78   https://twitter.com/rachel2195/status/87685077...                14
# 566  https://twitter.com/dog_rates/status/779056095...                13
# 469  https://twitter.com/dog_rates/status/790946055...                12
#
#      rating_denominator      name doggo floofer  pupper  puppo
# 78                   10  Unnammed  None    None  pupper   None
# 566                  10  Unnammed  None    None    None   None
# 469                  10     Betty  None    None    None  puppo

# %%
archive.drop(retweets.index, inplace=True)
archive.drop(['in_reply_to_user_id','in_reply_to_status_id',
              'retweeted_status_id','retweeted_status_user_id'], axis=1, inplace=True)

# %%
archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2175 non-null object
# timestamp             2175 non-null datetime64[ns]
# source                2175 non-null object
# text                  2175 non-null object
# expanded_urls         2117 non-null object
# rating_numerator      2175 non-null int64
# rating_denominator    2175 non-null int64
# name                  2175 non-null object
# doggo                 2175 non-null object
# floofer               2175 non-null object
# pupper                2175 non-null object
# puppo                 2175 non-null object
# dtypes: datetime64[ns](1), int64(2), object(9)
# memory usage: 220.9+ KB

# %% [markdown]
# ## 3.6 - Dog Stage

# %%
archive[['doggo','floofer','pupper','puppo']].describe()
# Out:
#        doggo floofer pupper puppo
# count   2175    2175   2175  2175
# unique     2       2      2     2
# top     None    None   None  None
# freq    2088    2165   1941  2150

# %%
archive['Stage'] = ''
archive['doggo'].replace('None','',inplace=True)
archive['pupper'].replace('None','',inplace=True)
archive['floofer'].replace('None','',inplace=True)
archive['puppo'].replace('None','',inplace=True)

# %%
archive[['doggo','floofer','pupper','puppo']].describe()
# Out:
#        doggo floofer pupper puppo
# count   2175    2175   2175  2175
# unique     2       2      2     2
# top
# freq    2088    2165   1941  2150

# %%
archive['Stage'] = archive['pupper']+archive['floofer']+archive['puppo']+archive['doggo']

# %%
archive[['doggo','floofer','pupper','puppo']].describe()
# Out:
#        doggo floofer pupper puppo
# count   2175    2175   2175  2175
# unique     2       2      2     2
# top
# freq    2088    2165   1941  2150

# %%
archive[['doggo','floofer','pupper','puppo']].nunique()
# Out:
# doggo      2
# floofer    2
# pupper     2
# puppo      2
# dtype: int64

# %% [markdown]
# **Interseting** next cells will show records of tweets with combined stages.

# %%
archive.Stage.unique()
# Out:
# array(['', 'doggo', 'puppo', 'pupper', 'floofer', 'puppodoggo',
#        'flooferdoggo', 'pupperdoggo'], dtype=object)

# %%
archive.Stage.replace(archive.Stage.unique()[0],'Undefined',inplace=True)

# %%
archive.query('Stage=="flooferdoggo"|Stage=="pupperdoggo"|Stage=="puppodoggo"').count()
# Out:
# tweet_id              12
# timestamp             12
# source                12
# text                  12
# expanded_urls         12
# rating_numerator      12
# rating_denominator    12
# name                  12
# doggo                 12
# floofer               12
# pupper                12
# puppo                 12
# Stage                 12
# dtype: int64

# %%
archive.query('Stage !="" ').sample(5)
# Out:
#                 tweet_id           timestamp              source  \
# 1949  673689733134946305 2015-12-07 02:25:23  Twitter for iPhone
# 1001  747933425676525569 2016-06-28 23:23:19  Twitter for iPhone
# 915   757354760399941633 2016-07-24 23:20:20  Twitter for iPhone
# 1027  746056683365994496 2016-06-23 19:05:49  Twitter for iPhone
# 1454  695446424020918272 2016-02-05 03:18:42  Twitter for iPhone
#
#                                                    text  \
# 1949  When you're having a blast and remember tomorr...
# 1001  Pls don't send more sherks. I don't care how s...
# 915   This is Devón (pronounced "Eric"). He forgot h...
# 1027  This is Arlen and Thumpelina. They are best pa...
# 1454  We normally don't rate unicorns but this one h...
#
#                                           expanded_urls  rating_numerator  \
# 1949  https://twitter.com/dog_rates/status/673689733...                11
# 1001  https://twitter.com/dog_rates/status/747933425...                11
# 915   https://twitter.com/dog_rates/status/757354760...                 8
# 1027  https://twitter.com/dog_rates/status/746056683...                11
# 1454  https://twitter.com/dog_rates/status/695446424...                12
#
#       rating_denominator      name doggo floofer pupper puppo      Stage
# 1949                  10  Unnammed                             Undefined
# 1001                  10  Unnammed                             Undefined
# 915                   10     Devón                             Undefined
# 1027                  10     Arlen                             Undefined
# 1454                  10  Unnammed                             Undefined

# %% [markdown]
# **Seprated stages columns** now not requried, can be removed.

# %%
archive.drop(['doggo','floofer','puppo','pupper'],axis=1,inplace=True)
archive.Stage.value_counts()
# Out:
# Undefined       1831
# pupper           224
# doggo             75
# puppo             24
# pupperdoggo       10
# floofer            9
# puppodoggo         1
# flooferdoggo       1
# Name: Stage, dtype: int64

# %%
archive['score'] = archive.rating_numerator / archive.rating_denominator
archive.drop(['rating_numerator','rating_denominator'],axis=1,inplace=True)

# %%
archive.sample(5)
# Out:
#                 tweet_id           timestamp              source  \
# 2087  670797304698376195 2015-11-29 02:51:54  Twitter for iPhone
# 2097  670733412878163972 2015-11-28 22:38:01  Twitter for iPhone
# 1516  690959652130045952 2016-01-23 18:09:53  Twitter for iPhone
# 296   837366284874571778 2017-03-02 18:17:34  Twitter for iPhone
# 1182  718971898235854848 2016-04-10 01:20:33  Twitter for iPhone
#
#                                                    text  \
# 2087  This is Trigger. He was minding his own busine...
# 2097  This is Jerry. He's a great listener. Low main...
# 1516  This golden is happy to refute the soft mouth ...
# 296   This is Lucy. She has a portrait of herself on...
# 1182  This is Sadie. She is prepared for battle. 10/...
#
#                                           expanded_urls      name      Stage  \
# 2087  https://twitter.com/dog_rates/status/670797304...   Trigger  Undefined
# 2097  https://twitter.com/dog_rates/status/670733412...     Jerry  Undefined
# 1516  https://twitter.com/dog_rates/status/690959652...  Unnammed  Undefined
# 296   https://twitter.com/dog_rates/status/837366284...      Lucy  Undefined
# 1182  https://twitter.com/dog_rates/status/718971898...     Sadie  Undefined
#
#       score
# 2087    1.1
# 2097    0.8
# 1516    1.1
# 296     1.3
# 1182    1.0

# %% [markdown]
# # 4 - Image Prediction

# %%
image_prediction.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %% [markdown]
# ## 4.1 - tweet_id Column fix

# %%
image_prediction['tweet_id'] = image_prediction.tweet_id.astype(str)
image_prediction.isnull().sum()
# Out:
# tweet_id    0
# jpg_url     0
# img_num     0
# p1          0
# p1_conf     0
# p1_dog      0
# p2          0
# p2_conf     0
# p2_dog      0
# p3          0
# p3_conf     0
# p3_dog      0
# dtype: int64

# %% [markdown]
# ## 4.2 - Removal of records of non-dog images

# %%
not_dogs = (image_prediction.p1_dog==False) & (image_prediction.p2_dog==False) & (image_prediction.p3_dog==False)
print('Number of records that dont seem to be dogs: ' ,+ not_dogs.sum())
# Out:
# Number of records that dont seem to be dogs:  324

# %%
index = image_prediction[not_dogs].index
image_prediction.drop(index,inplace=True)

image_prediction.drop(['p1_dog','p2_dog','p3_dog'],axis=1,inplace=True)
image_prediction.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf                  p2   p2_conf  \
# 0        1  Welsh_springer_spaniel  0.465074              collie  0.156665
# 1        1                 redbone  0.506826  miniature_pinscher  0.074192
# 2        1         German_shepherd  0.596461            malinois  0.138584
# 3        1     Rhodesian_ridgeback  0.408143             redbone  0.360687
# 4        1      miniature_pinscher  0.560311          Rottweiler  0.243682
#
#                     p3   p3_conf
# 0    Shetland_sheepdog  0.061428
# 1  Rhodesian_ridgeback  0.072010
# 2           bloodhound  0.116197
# 3   miniature_pinscher  0.222752
# 4             Doberman  0.154629

# %%
image_prediction['Pt'] = (image_prediction['p1_conf'] + image_prediction['p1_conf'] + image_prediction['p1_conf'])/3
image_prediction.drop(['p1_conf','p2_conf','p3_conf'],axis=1,inplace=True)

# %%
non_jpg_urls = image_prediction.jpg_url.str.contains('video')
sum(non_jpg_urls)
# Out:
# 63

# %%
image_prediction.drop(image_prediction[non_jpg_urls].index,inplace=True)

# %% [markdown]
# # 5 - Json Data

# %%
tweet_df.head()
# Out:
#    favorite_count                                          full_text  \
# 0           39467  This is Phineas. He's a mystical boy. Only eve...
# 1           33819  This is Tilly. She's just checking pup on you....
# 2           25461  This is Archie. He is a rare Norwegian Pouncin...
# 3           42908  This is Darla. She commenced a snooze mid meal...
# 4           41048  This is Franklin. He would like you to stop ca...
#
#    retweet_count            tweet_id
# 0           8853  892420643555336193
# 1           6514  892177421306343426
# 2           4328  891815181378084864
# 3           8964  891689557279858688
# 4           9774  891327558926688256

# %%
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 4 columns):
# favorite_count    2354 non-null int64
# full_text         2354 non-null object
# retweet_count     2354 non-null int64
# tweet_id          2354 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 73.6+ KB

# %% [markdown]
# ## 5.1 - tweet_id column fix

# %%
tweet_df['tweet_id'] = tweet_df.tweet_id.astype(str)

# %%
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 4 columns):
# favorite_count    2354 non-null int64
# full_text         2354 non-null object
# retweet_count     2354 non-null int64
# tweet_id          2354 non-null object
# dtypes: int64(2), object(2)
# memory usage: 73.6+ KB

# %%
tweet_df.isnull().sum()
# Out:
# favorite_count    0
# full_text         0
# retweet_count     0
# tweet_id          0
# dtype: int64

# %% [markdown]
# # 6 - Merge Section

# %%
archive_clean = archive.copy()
image_p_clean = image_prediction.copy()
tweet_df_clean = tweet_df.copy()

# %% [markdown]
# ## 6.1 - Merge dataframes & Master df

# %%
merge_df = pd.merge(archive_clean,image_p_clean, on='tweet_id')

# %%
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1629 entries, 0 to 1628
# Data columns (total 14 columns):
# tweet_id         1629 non-null object
# timestamp        1629 non-null datetime64[ns]
# source           1629 non-null object
# text             1629 non-null object
# expanded_urls    1629 non-null object
# name             1629 non-null object
# Stage            1629 non-null object
# score            1629 non-null float64
# jpg_url          1629 non-null object
# img_num          1629 non-null int64
# p1               1629 non-null object
# p2               1629 non-null object
# p3               1629 non-null object
# Pt               1629 non-null float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(10)
# memory usage: 190.9+ KB

# %%
master_df = pd.merge(merge_df,tweet_df_clean, on='tweet_id')

# %%
sum(master_df['text'] != master_df['full_text'])
# Out:
# 0

# %%
master_df.drop('text',axis=1,inplace=True)
master_df.describe()
# Out:
#              score      img_num           Pt  favorite_count  retweet_count
# count  1629.000000  1629.000000  1629.000000     1629.000000    1629.000000
# mean      1.085073     1.223450     0.610820     8790.402087    2568.149785
# std       0.252923     0.584749     0.265673    11360.207202    3665.746983
# min       0.000000     1.000000     0.044333       81.000000      16.000000
# 25%       1.000000     1.000000     0.382234     2115.000000     632.000000
# 50%       1.100000     1.000000     0.610946     4236.000000    1397.000000
# 75%       1.200000     1.000000     0.858513    11310.000000    3144.000000
# max       7.500000     4.000000     0.999984   132810.000000   48265.000000

# %% [markdown]
# # 7 - Visualization

# %%
master_df.corr()
# Out:
#                    score   img_num        Pt  favorite_count  retweet_count
# score           1.000000  0.125718  0.090594        0.311967       0.253048
# img_num         0.125718  1.000000  0.212340        0.155963       0.151376
# Pt              0.090594  0.212340  1.000000        0.116906       0.107653
# favorite_count  0.311967  0.155963  0.116906        1.000000       0.926043
# retweet_count   0.253048  0.151376  0.107653        0.926043       1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(master_df.corr(),annot=True,cmap='coolwarm',linewidths=1);

# %%
master_df.score.plot(color='g');

# %%
by_year = master_df.timestamp.dt.year
plt.figure(figsize=(8,8))
master_df.groupby(by_year).tweet_id.count().plot(kind='pie',explode=[0.01,0.01,0.01])
plt.title('Number of tweets per Year')
plt.ylabel('');

# %%
by_year = master_df.timestamp.dt.year
plt.figure(figsize=(8,8))
master_df.groupby(by_year).favorite_count.count().plot(kind='pie',explode=[0.01,0.01,0.01])
plt.title('Number of tweets per Year')
plt.ylabel('');

# %%
master_df.groupby(by_year).favorite_count.count()
# Out:
# timestamp
# 2015    507
# 2016    819
# 2017    303
# Name: favorite_count, dtype: int64

# %%
master_df.groupby(by_year).retweet_count.count()
# Out:
# timestamp
# 2015    507
# 2016    819
# 2017    303
# Name: retweet_count, dtype: int64

# %%
master_df.groupby(by_year).tweet_id.count()
# Out:
# timestamp
# 2015    507
# 2016    819
# 2017    303
# Name: tweet_id, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.scatter(master_df['retweet_count'], master_df['favorite_count']);

# %%
master_df
# Out:
#                 tweet_id           timestamp              source  \
# 0     892177421306343426 2017-08-01 00:17:27  Twitter for iPhone
# 1     891815181378084864 2017-07-31 00:18:03  Twitter for iPhone
# 2     891689557279858688 2017-07-30 15:58:51  Twitter for iPhone
# 3     891327558926688256 2017-07-29 16:00:24  Twitter for iPhone
# 4     891087950875897856 2017-07-29 00:08:17  Twitter for iPhone
# 1617  Let's hope this flight isn't Malaysian (lol). ...            174
# 1618  Here we have a northern speckled Rhododendron....             67
# 1619  This is the happiest dog you will ever see. Ve...            232
# 1620  Here is the Rand Paul of retrievers folks! He'...             61
# 1621  My oh my. This is a rare blond Canadian terrie...            146
# 1622  Here is a Siberian heavily armored polar bear ...            261
# 1623  This is a truly beautiful English Wilson Staff...             60
# 1624  Here we have a 1949 1st generation vulpix. Enj...             41
# 1625  This is a purebred Piers Morgan. Loves to Netf...            147
# 1626  Here is a very happy pup. Big fan of well-main...             47
# 1627  This is a western brown Mitsubishi terrier. Up...             48
# 1628  Here we have a Japanese Irish Setter. Lost eye...            532
#
# [1629 rows x 16 columns]

# %%
master_df.jpg_url.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(10,8))
master_df.name.value_counts()
# Out:
# Unnammed        439
# Charlie          10
# Lucy             10
# Cooper           10
# Tucker            9
# Penny             8
# Oliver            8
# Winston           7
# Sadie             7
# Daisy             7
# the               6
# Jax               6
# Toby              6
# Lola              6
# Koda              6
# Stanley           5
# Oscar             5
# Bella             5
# Bo                5
# Milo              4
# George            4
# an                4
# Cassie            4
# Dave              4
# Bailey            4
# Brody             4
# Larry             4
# Sophie            4
# Alfie             4
# Bentley           4
#                ...
# Brandi            1
# Tuco              1
# Jebberson         1
# Marlee            1
# Harlso            1
# Jay               1
# Pickles           1
# Dudley            1
# Kirby             1
# Rueben            1
# Kane              1
# Jangle            1
# Storkson          1
# Brownie           1
# Paull             1
# Ralphie           1
# Maximus           1
# Mosby             1
# Canela            1
# Willow            1
# Noosh             1
# Shakespeare       1
# Eve               1
# Harper            1
# Edgar             1
# Charleson         1
# Jerome            1
# unacceptable      1
# Klein             1
# Newt              1
# Name: name, Length: 836, dtype: int64

# %%
master_df.source.value_counts()
# Out:
# Twitter for iPhone    1603
# Twitter Web Client      17
# TweetDeck                9
# Name: source, dtype: int64

# %%
master_df.columns
# Out:
# Index(['tweet_id', 'timestamp', 'source', 'expanded_urls', 'name', 'Stage',
#        'score', 'jpg_url', 'img_num', 'p1', 'p2', 'p3', 'Pt', 'favorite_count',
#        'full_text', 'retweet_count'],
#       dtype='object')

# %%
master_df.favorite_count.hist(alpha=0.5 , label='Favorites')
master_df.retweet_count.hist(alpha=0.5 , label='Retweets')
plt.title('Favorites / Retweets Distribuion')
plt.xlabel('Value')
plt.ylabel('Count')
plt.legend();

# %%
master_df.p1.nunique()
# Out:
# 209

# %%
by_month = master_df.timestamp.dt.month_name()
explode=np.zeros(12)
plt.figure(figsize=(8,8))
master_df.groupby(by_month).tweet_id.count().plot(kind='pie' , explode=explode+0.08 , autopct='%1.1f%%',
        shadow=True, startangle=30)
plt.title('Percentage of tweets / Month')
plt.ylabel('');

# %%
explode=np.zeros(3)
plt.figure(figsize=(8,8))
master_df.groupby(by_year).tweet_id.count().plot(kind='pie' , explode=explode+0.03 , autopct='%1.1f%%',
        shadow=True, startangle=30)
plt.title('Percentage of tweets / Year')
plt.ylabel('');
